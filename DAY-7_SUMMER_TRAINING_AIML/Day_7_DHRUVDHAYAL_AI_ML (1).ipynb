# %% [markdown]
# #Now, we directly acess the data values from the Drive Directly!

# %%
from google.colab import drive;
drive.mount('/gdrive');
# Out:
# Mounted at /gdrive

# %%
# !unzip '/content/drive/MyDrive/Colab Notebooks/orl_face/orl_face.zip' -d '/content/drive/MyDrive/Colab Notebooks/orl_face'
# Out:
# Archive:  /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face.zip
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/.DS_Store
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/__MACOSX/
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/__MACOSX/orl_face/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/__MACOSX/orl_face/._.DS_Store
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u1/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u1/1.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/__MACOSX/orl_face/u1/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/__MACOSX/orl_face/u1/._1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u1/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u1/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u1/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u1/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u1/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u1/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u1/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u1/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u1/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u10/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u10/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u10/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u10/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u10/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u10/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u10/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u10/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u10/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u10/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u10/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u11/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u11/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u11/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u11/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u11/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u11/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u11/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u11/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u11/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u11/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u11/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u12/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u12/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u12/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u12/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u12/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u12/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u12/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u12/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u12/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u12/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u12/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u13/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u13/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u13/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u13/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u13/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u13/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u13/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u13/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u13/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u13/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u13/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u14/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u14/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u14/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u14/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u14/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u14/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u14/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u14/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u14/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u14/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u14/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u15/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u15/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u15/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u15/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u15/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u15/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u15/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u15/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u15/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u15/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u15/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u16/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u16/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u16/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u16/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u16/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u16/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u16/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u16/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u16/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u16/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u16/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u17/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u17/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u17/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u17/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u17/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u17/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u17/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u17/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u17/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u17/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u17/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u18/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u18/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u18/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u18/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u18/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u18/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u18/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u18/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u18/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u18/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u18/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u19/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u19/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u19/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u19/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u19/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u19/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u19/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u19/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u19/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u19/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u19/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u2/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u2/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u2/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u2/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u2/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u2/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u2/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u2/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u2/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u2/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u2/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u20/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u20/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u20/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u20/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u20/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u20/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u20/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u20/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u20/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u20/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u20/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u21/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u21/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u21/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u21/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u21/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u21/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u21/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u21/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u21/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u21/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u21/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u22/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u22/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u22/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u22/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u22/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u22/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u22/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u22/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u22/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u22/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u22/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u23/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u23/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u23/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u23/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u23/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u23/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u23/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u23/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u23/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u23/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u23/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u24/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u24/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u24/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u24/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u24/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u24/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u24/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u24/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u24/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u24/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u24/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u25/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u25/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u25/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u25/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u25/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u25/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u25/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u25/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u25/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u25/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u25/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u26/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u26/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u26/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u26/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u26/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u26/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u26/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u26/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u26/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u26/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u26/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u27/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u27/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u27/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u27/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u27/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u27/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u27/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u27/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u27/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u27/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u27/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u28/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u28/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u28/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u28/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u28/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u28/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u28/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u28/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u28/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u28/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u28/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u29/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u29/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u29/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u29/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u29/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u29/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u29/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u29/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u29/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u29/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u29/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u3/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u3/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u3/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u3/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u3/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u3/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u3/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u3/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u3/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u3/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u3/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u30/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u30/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u30/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u30/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u30/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u30/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u30/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u30/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u30/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u30/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u30/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u31/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u31/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u31/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u31/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u31/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u31/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u31/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u31/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u31/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u31/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u31/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u32/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u32/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u32/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u32/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u32/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u32/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u32/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u32/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u32/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u32/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u32/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u33/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u33/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u33/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u33/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u33/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u33/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u33/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u33/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u33/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u33/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u33/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u34/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u34/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u34/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u34/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u34/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u34/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u34/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u34/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u34/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u34/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u34/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u35/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u35/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u35/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u35/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u35/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u35/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u35/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u35/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u35/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u35/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u35/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u36/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u36/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u36/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u36/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u36/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u36/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u36/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u36/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u36/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u36/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u36/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u37/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u37/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u37/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u37/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u37/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u37/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u37/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u37/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u37/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u37/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u37/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u38/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u38/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u38/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u38/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u38/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u38/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u38/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u38/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u38/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u38/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u38/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u39/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u39/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u39/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u39/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u39/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u39/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u39/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u39/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u39/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u39/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u39/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u4/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u4/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u4/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u4/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u4/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u4/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u4/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u4/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u4/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u4/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u4/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u40/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u40/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u40/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u40/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u40/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u40/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u40/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u40/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u40/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u40/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u40/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u5/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u5/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u5/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u5/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u5/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u5/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u5/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u5/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u5/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u5/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u5/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u6/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u6/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u6/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u6/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u6/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u6/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u6/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u6/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u6/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u6/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u6/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u7/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u7/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u7/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u7/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u7/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u7/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u7/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u7/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u7/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u7/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u7/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u8/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u8/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u8/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u8/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u8/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u8/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u8/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u8/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u8/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u8/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u8/9.png
#    creating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u9/
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u9/1.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u9/10.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u9/2.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u9/3.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u9/4.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u9/5.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u9/6.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u9/7.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u9/8.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u9/9.png

# %%
#Now, Importing the Images data from the unzip files.
import matplotlib.pyplot as plt;
import matplotlib.image as mimg;
import numpy as np;
import pandas as pd;

#Now, we need to read the values of the Data from a Drive.
user_name=24; #Labels.
samples_no=6; #Define the Variable Sample_Numbers.
path='/content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u%d/%d.png'%(user_name,samples_no);

#Now, we need to read the data from images.
imag=mimg.imread(path);
print("\n 1. Type of the Image is: ",type(imag));
print("\n 2. Length of the Image is: ",imag.shape);
print("\n");

#Now, we need to plot the Image.
plt.figure(1,figsize=(5,10));
plt.imshow(imag,cmap='gray');
plt.axis("off");
plt.show();
# Out:
#  1. Type of the Image is:  <class 'numpy.ndarray'>
#
#  2. Length of the Image is:  (112, 92)

# %%
#Now, convert 2-D Images it into 1-D Images by using the Flatten.
feat=imag.reshape(1,-1);
print("\n 1. Length of the Images: ",imag.shape);
print("\n 2. Length of the Features: ",feat.shape);
print("\n --> Range: ",imag.min()," - ",imag.max());
# Out:
#  1. Length of the Images:  (112, 92)
#
#  2. Length of the Features:  (1, 10304)
#
#  --> Range:  0.05490196  -  0.89411765

# %%
#Logic to acess all the samples of the User.
#Of the Valued Users.
total_sample=400;
user_name=26;
sample_no=6;
data=np.zeros((total_sample,imag.shape[0]*imag.shape[1]));
label=np.zeros((total_sample));
images=np.zeros((total_sample,imag.shape[0],imag.shape[1]));
index=-1;
for i in range(1,41,1):
  for j in range(1,11,1):
    index=index+1;
    #acess any of the single image.
    user_name=i;
    sample_no=j;
    path='/content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u%d/%d.png'%(user_name,sample_no);
    #reading the Image.
    im=mimg.imread(path);
    data[index,:]=feat
    label[index]=i
    images[index,:,:]=im
    print("user num ",i,'samp no',j,'processed...');
# Out:
# user num  1 samp no 1 processed...
# user num  1 samp no 2 processed...
# user num  1 samp no 3 processed...
# user num  1 samp no 4 processed...
# user num  1 samp no 5 processed...
# user num  1 samp no 6 processed...
# user num  1 samp no 7 processed...
# user num  1 samp no 8 processed...
# user num  1 samp no 9 processed...
# user num  1 samp no 10 processed...
# user num  2 samp no 1 processed...
# user num  2 samp no 2 processed...
# user num  2 samp no 3 processed...
# user num  2 samp no 4 processed...
# user num  2 samp no 5 processed...
# user num  2 samp no 6 processed...
# user num  2 samp no 7 processed...
# user num  2 samp no 8 processed...
# user num  2 samp no 9 processed...
# user num  2 samp no 10 processed...
# user num  3 samp no 1 processed...
# user num  3 samp no 2 processed...
# user num  3 samp no 3 processed...
# user num  3 samp no 4 processed...
# user num  3 samp no 5 processed...
# user num  3 samp no 6 processed...
# user num  3 samp no 7 processed...
# user num  3 samp no 8 processed...
# user num  3 samp no 9 processed...
# user num  3 samp no 10 processed...
# user num  4 samp no 1 processed...
# user num  4 samp no 2 processed...
# user num  4 samp no 3 processed...
# user num  4 samp no 4 processed...
# user num  4 samp no 5 processed...
# user num  4 samp no 6 processed...
# user num  4 samp no 7 processed...
# user num  4 samp no 8 processed...
# user num  4 samp no 9 processed...
# user num  4 samp no 10 processed...
# user num  5 samp no 1 processed...
# user num  5 samp no 2 processed...
# user num  5 samp no 3 processed...
# user num  5 samp no 4 processed...
# user num  5 samp no 5 processed...
# user num  5 samp no 6 processed...
# user num  5 samp no 7 processed...
# user num  5 samp no 8 processed...
# user num  5 samp no 9 processed...
# user num  5 samp no 10 processed...
# user num  6 samp no 1 processed...
# user num  6 samp no 2 processed...
# user num  6 samp no 3 processed...
# user num  6 samp no 4 processed...
# user num  6 samp no 5 processed...
# user num  6 samp no 6 processed...
# user num  6 samp no 7 processed...
# user num  6 samp no 8 processed...
# user num  6 samp no 9 processed...
# user num  6 samp no 10 processed...
# user num  7 samp no 1 processed...
# user num  7 samp no 2 processed...
# user num  7 samp no 3 processed...
# user num  7 samp no 4 processed...
# user num  7 samp no 5 processed...
# user num  7 samp no 6 processed...
# user num  7 samp no 7 processed...
# user num  7 samp no 8 processed...
# user num  7 samp no 9 processed...
# user num  7 samp no 10 processed...
# user num  8 samp no 1 processed...
# user num  8 samp no 2 processed...
# user num  8 samp no 3 processed...
# user num  8 samp no 4 processed...
# user num  8 samp no 5 processed...
# user num  8 samp no 6 processed...
# user num  8 samp no 7 processed...
# user num  8 samp no 8 processed...
# user num  8 samp no 9 processed...
# user num  8 samp no 10 processed...
# user num  9 samp no 1 processed...
# user num  9 samp no 2 processed...
# user num  9 samp no 3 processed...
# user num  9 samp no 4 processed...
# user num  9 samp no 5 processed...
# user num  9 samp no 6 processed...
# user num  9 samp no 7 processed...
# user num  9 samp no 8 processed...
# user num  9 samp no 9 processed...
# user num  9 samp no 10 processed...
# user num  10 samp no 1 processed...
# user num  10 samp no 2 processed...
# user num  10 samp no 3 processed...
# user num  10 samp no 4 processed...
# user num  10 samp no 5 processed...
# user num  10 samp no 6 processed...
# user num  10 samp no 7 processed...
# user num  10 samp no 8 processed...
# user num  10 samp no 9 processed...
# user num  10 samp no 10 processed...
# user num  11 samp no 1 processed...
# user num  11 samp no 2 processed...
# user num  11 samp no 3 processed...
# user num  11 samp no 4 processed...
# user num  11 samp no 5 processed...
# user num  11 samp no 6 processed...
# user num  11 samp no 7 processed...
# user num  11 samp no 8 processed...
# user num  11 samp no 9 processed...
# user num  11 samp no 10 processed...
# user num  12 samp no 1 processed...
# user num  12 samp no 2 processed...
# user num  12 samp no 3 processed...
# user num  12 samp no 4 processed...
# user num  12 samp no 5 processed...
# user num  12 samp no 6 processed...
# user num  12 samp no 7 processed...
# user num  12 samp no 8 processed...
# user num  12 samp no 9 processed...
# user num  12 samp no 10 processed...
# user num  13 samp no 1 processed...
# user num  13 samp no 2 processed...
# user num  13 samp no 3 processed...
# user num  13 samp no 4 processed...
# user num  13 samp no 5 processed...
# user num  13 samp no 6 processed...
# user num  13 samp no 7 processed...
# user num  13 samp no 8 processed...
# user num  13 samp no 9 processed...
# user num  13 samp no 10 processed...
# user num  14 samp no 1 processed...
# user num  14 samp no 2 processed...
# user num  14 samp no 3 processed...
# user num  14 samp no 4 processed...
# user num  14 samp no 5 processed...
# user num  14 samp no 6 processed...
# user num  14 samp no 7 processed...
# user num  14 samp no 8 processed...
# user num  14 samp no 9 processed...
# user num  14 samp no 10 processed...
# user num  15 samp no 1 processed...
# user num  15 samp no 2 processed...
# user num  15 samp no 3 processed...
# user num  15 samp no 4 processed...
# user num  15 samp no 5 processed...
# user num  15 samp no 6 processed...
# user num  15 samp no 7 processed...
# user num  15 samp no 8 processed...
# user num  15 samp no 9 processed...
# user num  15 samp no 10 processed...
# user num  16 samp no 1 processed...
# user num  16 samp no 2 processed...
# user num  16 samp no 3 processed...
# user num  16 samp no 4 processed...
# user num  16 samp no 5 processed...
# user num  16 samp no 6 processed...
# user num  16 samp no 7 processed...
# user num  16 samp no 8 processed...
# user num  16 samp no 9 processed...
# user num  16 samp no 10 processed...
# user num  17 samp no 1 processed...
# user num  17 samp no 2 processed...
# user num  17 samp no 3 processed...
# user num  17 samp no 4 processed...
# user num  17 samp no 5 processed...
# user num  17 samp no 6 processed...
# user num  17 samp no 7 processed...
# user num  17 samp no 8 processed...
# user num  17 samp no 9 processed...
# user num  17 samp no 10 processed...
# user num  18 samp no 1 processed...
# user num  18 samp no 2 processed...
# user num  18 samp no 3 processed...
# user num  18 samp no 4 processed...
# user num  18 samp no 5 processed...
# user num  18 samp no 6 processed...
# user num  18 samp no 7 processed...
# user num  18 samp no 8 processed...
# user num  18 samp no 9 processed...
# user num  18 samp no 10 processed...
# user num  19 samp no 1 processed...
# user num  19 samp no 2 processed...
# user num  19 samp no 3 processed...
# user num  19 samp no 4 processed...
# user num  19 samp no 5 processed...
# user num  19 samp no 6 processed...
# user num  19 samp no 7 processed...
# user num  19 samp no 8 processed...
# user num  19 samp no 9 processed...
# user num  19 samp no 10 processed...
# user num  20 samp no 1 processed...
# user num  20 samp no 2 processed...
# user num  20 samp no 3 processed...
# user num  20 samp no 4 processed...
# user num  20 samp no 5 processed...
# user num  20 samp no 6 processed...
# user num  20 samp no 7 processed...
# user num  20 samp no 8 processed...
# user num  20 samp no 9 processed...
# user num  20 samp no 10 processed...
# user num  21 samp no 1 processed...
# user num  21 samp no 2 processed...
# user num  21 samp no 3 processed...
# user num  21 samp no 4 processed...
# user num  21 samp no 5 processed...
# user num  21 samp no 6 processed...
# user num  21 samp no 7 processed...
# user num  21 samp no 8 processed...
# user num  21 samp no 9 processed...
# user num  21 samp no 10 processed...
# user num  22 samp no 1 processed...
# user num  22 samp no 2 processed...
# user num  22 samp no 3 processed...
# user num  22 samp no 4 processed...
# user num  22 samp no 5 processed...
# user num  22 samp no 6 processed...
# user num  22 samp no 7 processed...
# user num  22 samp no 8 processed...
# user num  22 samp no 9 processed...
# user num  22 samp no 10 processed...
# user num  23 samp no 1 processed...
# user num  23 samp no 2 processed...
# user num  23 samp no 3 processed...
# user num  23 samp no 4 processed...
# user num  23 samp no 5 processed...
# user num  23 samp no 6 processed...
# user num  23 samp no 7 processed...
# user num  23 samp no 8 processed...
# user num  23 samp no 9 processed...
# user num  23 samp no 10 processed...
# user num  24 samp no 1 processed...
# user num  24 samp no 2 processed...
# user num  24 samp no 3 processed...
# user num  24 samp no 4 processed...
# user num  24 samp no 5 processed...
# user num  24 samp no 6 processed...
# user num  24 samp no 7 processed...
# user num  24 samp no 8 processed...
# user num  24 samp no 9 processed...
# user num  24 samp no 10 processed...
# user num  25 samp no 1 processed...
# user num  25 samp no 2 processed...
# user num  25 samp no 3 processed...
# user num  25 samp no 4 processed...
# user num  25 samp no 5 processed...
# user num  25 samp no 6 processed...
# user num  25 samp no 7 processed...
# user num  25 samp no 8 processed...
# user num  25 samp no 9 processed...
# user num  25 samp no 10 processed...
# user num  26 samp no 1 processed...
# user num  26 samp no 2 processed...
# user num  26 samp no 3 processed...
# user num  26 samp no 4 processed...
# user num  26 samp no 5 processed...
# user num  26 samp no 6 processed...
# user num  26 samp no 7 processed...
# user num  26 samp no 8 processed...
# user num  26 samp no 9 processed...
# user num  26 samp no 10 processed...
# user num  27 samp no 1 processed...
# user num  27 samp no 2 processed...
# user num  27 samp no 3 processed...
# user num  27 samp no 4 processed...
# user num  27 samp no 5 processed...
# user num  27 samp no 6 processed...
# user num  27 samp no 7 processed...
# user num  27 samp no 8 processed...
# user num  27 samp no 9 processed...
# user num  27 samp no 10 processed...
# user num  28 samp no 1 processed...
# user num  28 samp no 2 processed...
# user num  28 samp no 3 processed...
# user num  28 samp no 4 processed...
# user num  28 samp no 5 processed...
# user num  28 samp no 6 processed...
# user num  28 samp no 7 processed...
# user num  28 samp no 8 processed...
# user num  28 samp no 9 processed...
# user num  28 samp no 10 processed...
# user num  29 samp no 1 processed...
# user num  29 samp no 2 processed...
# user num  29 samp no 3 processed...
# user num  29 samp no 4 processed...
# user num  29 samp no 5 processed...
# user num  29 samp no 6 processed...
# user num  29 samp no 7 processed...
# user num  29 samp no 8 processed...
# user num  29 samp no 9 processed...
# user num  29 samp no 10 processed...
# user num  30 samp no 1 processed...
# user num  30 samp no 2 processed...
# user num  30 samp no 3 processed...
# user num  30 samp no 4 processed...
# user num  30 samp no 5 processed...
# user num  30 samp no 6 processed...
# user num  30 samp no 7 processed...
# user num  30 samp no 8 processed...
# user num  30 samp no 9 processed...
# user num  30 samp no 10 processed...
# user num  31 samp no 1 processed...
# user num  31 samp no 2 processed...
# user num  31 samp no 3 processed...
# user num  31 samp no 4 processed...
# user num  31 samp no 5 processed...
# user num  31 samp no 6 processed...
# user num  31 samp no 7 processed...
# user num  31 samp no 8 processed...
# user num  31 samp no 9 processed...
# user num  31 samp no 10 processed...
# user num  32 samp no 1 processed...
# user num  32 samp no 2 processed...
# user num  32 samp no 3 processed...
# user num  32 samp no 4 processed...
# user num  32 samp no 5 processed...
# user num  32 samp no 6 processed...
# user num  32 samp no 7 processed...
# user num  32 samp no 8 processed...
# user num  32 samp no 9 processed...
# user num  32 samp no 10 processed...
# user num  33 samp no 1 processed...
# user num  33 samp no 2 processed...
# user num  33 samp no 3 processed...
# user num  33 samp no 4 processed...
# user num  33 samp no 5 processed...
# user num  33 samp no 6 processed...
# user num  33 samp no 7 processed...
# user num  33 samp no 8 processed...
# user num  33 samp no 9 processed...
# user num  33 samp no 10 processed...
# user num  34 samp no 1 processed...
# user num  34 samp no 2 processed...
# user num  34 samp no 3 processed...
# user num  34 samp no 4 processed...
# user num  34 samp no 5 processed...
# user num  34 samp no 6 processed...
# user num  34 samp no 7 processed...
# user num  34 samp no 8 processed...
# user num  34 samp no 9 processed...
# user num  34 samp no 10 processed...
# user num  35 samp no 1 processed...
# user num  35 samp no 2 processed...
# user num  35 samp no 3 processed...
# user num  35 samp no 4 processed...
# user num  35 samp no 5 processed...
# user num  35 samp no 6 processed...
# user num  35 samp no 7 processed...
# user num  35 samp no 8 processed...
# user num  35 samp no 9 processed...
# user num  35 samp no 10 processed...
# user num  36 samp no 1 processed...
# user num  36 samp no 2 processed...
# user num  36 samp no 3 processed...
# user num  36 samp no 4 processed...
# user num  36 samp no 5 processed...
# user num  36 samp no 6 processed...
# user num  36 samp no 7 processed...
# user num  36 samp no 8 processed...
# user num  36 samp no 9 processed...
# user num  36 samp no 10 processed...
# user num  37 samp no 1 processed...
# user num  37 samp no 2 processed...
# user num  37 samp no 3 processed...
# user num  37 samp no 4 processed...
# user num  37 samp no 5 processed...
# user num  37 samp no 6 processed...
# user num  37 samp no 7 processed...
# user num  37 samp no 8 processed...
# user num  37 samp no 9 processed...
# user num  37 samp no 10 processed...
# user num  38 samp no 1 processed...
# user num  38 samp no 2 processed...
# user num  38 samp no 3 processed...
# user num  38 samp no 4 processed...
# user num  38 samp no 5 processed...
# user num  38 samp no 6 processed...
# user num  38 samp no 7 processed...
# user num  38 samp no 8 processed...
# user num  38 samp no 9 processed...
# user num  38 samp no 10 processed...
# user num  39 samp no 1 processed...
# user num  39 samp no 2 processed...
# user num  39 samp no 3 processed...
# user num  39 samp no 4 processed...
# user num  39 samp no 5 processed...
# user num  39 samp no 6 processed...
# user num  39 samp no 7 processed...
# user num  39 samp no 8 processed...
# user num  39 samp no 9 processed...
# user num  39 samp no 10 processed...
# user num  40 samp no 1 processed...
# user num  40 samp no 2 processed...
# user num  40 samp no 3 processed...
# user num  40 samp no 4 processed...
# user num  40 samp no 5 processed...
# user num  40 samp no 6 processed...
# user num  40 samp no 7 processed...
# user num  40 samp no 8 processed...
# user num  40 samp no 9 processed...
# user num  40 samp no 10 processed...

# %%
#Now, displaying the values of the Image.
plt.imshow(images[397,:,:],cmap='gray');
plt.axis('off');
plt.show();

# %% [markdown]
# #Now, we need to represent the values of the (5*5) Matrix.

# %%
#Importing all the Built-in Libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # Import matplotlib.pyplot

#Now, we need to show all the (5*5) Matrix Values.
plt.figure(1,figsize=(10,10));
for i in range(5):
  for j in range(5):
    num=np.random.randint(0,400);
    samples=images[num,:,:];
    la=label[num];
    plt.subplot(5,5,i*5+j+1) # Use plt to access subplot
    plt.imshow(samples,cmap='gray');
    plt.axis('off');
    plt.title(" "+str(int(la)));
#showing the Image (5*5) Matrix.
plt.show();

# %%
from sklearn import svm
import pandas as pd
X = data # Extract the data from the 'data' key
y =label # Use the target variable from the Iris dataset


# split the data into 70:30 ratio
Xtrain,Xtest,ytrain,ytest = model_selection.train_test_split(X,y,test_size=0.3,random_state=5)
print(Xtrain.shape,ytrain.shape)
print(Xtest.shape,ytest.shape)

ker = ['poly','linear','rbf']
c_value = [1,2,3]

# pre allocation of the result variable
result = np.zeros((len(ker),len(c_value)))
for i in range(len(ker)):
  for j in range(len(c_value)):
    # create the svm classifier
    orl_svm_model = svm.SVC(kernel=ker[i],gamma='scale',C=c_value[j])

    # train the model
    orl_svm_model = orl_svm_model.fit(Xtrain,ytrain)

    # predict the labels
    ypred = orl_svm_model.predict(Xtest)

    # accuracy
    acc = metrics.accuracy_score(ypred,ytest)
    #print("accuracy:", acc)
    result[i,j]=acc
print(result)

ResultDF = pd.DataFrame(result,index=ker,columns=["C=1","C=2","C=3"])
ResultDF
print("\n Showing in the form of the Graphical Methods!");
ResultDF.plot(kind='bar',figsize=(4,4))
# Out:
# (280, 10304) (280,)
# (120, 10304) (120,)
# [[0.00833333 0.00833333 0.00833333]
#  [0.00833333 0.00833333 0.00833333]
#  [0.00833333 0.00833333 0.00833333]]
#
#  Showing in the form of the Graphical Methods!
# <Axes: >

# %%
#Saving our trained model in the Google Drive.
#We, use the Joblib to save the models.
import joblib
# final best model
# kernel function - linear , C =1

orl_svm_model = svm.SVC(kernel='linear',gamma='scale',C=1)
# train the model
orl_svm_model = orl_svm_model.fit(Xtrain,ytrain)

# save the trained model
joblib.dump(orl_svm_model,'/content/drive/MyDrive/Colab Notebooks/orl_face_model.pkl')
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/orl_face_model.pkl']

# %%
#Show the random image from 1-10 , asked by the user to take as input form of parameter.
#Ask the user as ID to show that location image randomly.
import matplotlib.pyplot as plt;
import matplotlib.image as mimg;
import pandas as pd;
import numpy as np;

#Now, we simply ask from the User.
user_name=int(input("Enter the User ID: "));
sample_no=np.random.randint(8,10);
path='/content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u%d/%d.png'%(user_name,sample_no);

#Now, we need to show the value of the Image.
imag=mimg.imread(path);
print("\n");
plt.figure(1,figsize=(5,10));
plt.imshow(imag,cmap='gray');
plt.axis("off");
plt.title('Query Image');
plt.show();
# Out:
# Enter the User ID: 8

# %%
#We, make the trained model and save in the drive by using the joblib.
from sklearn import datasets, svm, metrics, model_selection;
import joblib;
import numpy as np;
import pandas as pd;

feat=imag.reshape(1,-1);

#Set the value of the Path_model where, we have to store the model in pkl. file on Drive.
path_model='/content/drive/MyDrive/Colab Notebooks/orl_face_model.pkl';

#Train the Model by the help of Classifications.
face_model=joblib.load(path_model);

#predict the image model by datasets.
result=face_model.predict(feat);

print("Prediction: ",int(result[0]));

#set the location of the zip image file.
path='/content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u%d/%d.png'%(result[0],1);

im_pred = mimg.imread(path)

plt.figure(1,(8,5))
plt.subplot(1,2,1)
plt.imshow(im,cmap='gray')
plt.axis('off')
plt.title("Query image")

plt.subplot(1,2,2)
plt.imshow(im_pred,cmap='gray')
plt.axis('off')
plt.title("predicted user")
# Out:
# Prediction:  4
# Text(0.5, 1.0, 'predicted user')

# %% [markdown]
# #Example of FP-(FALSE - POSITIVE), Very, Dangerous I check but I don't know where is the problem where all snippet is found to be correct, I refer to my friend's colab notebook for reviewing.

# %%
import matplotlib.image as mimg
import matplotlib.pyplot as plt
import numpy as np

# load the query image
usrId = int(input("Enter the user number:"))
samp = np.random.randint(1,10) # selecting any random sample number
path = "/content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u%d/%d.png"%(usrId,samp)

im = mimg.imread(path)

plt.figure(1,(5,5))
plt.imshow(im,cmap='gray')
plt.axis('off')
plt.title("Query image")
# Out:
# Enter the user number:25
# Text(0.5, 1.0, 'Query image')

# %%
import joblib
from sklearn import svm ,metrics
# calcualte the features of the query image
feat_query = im.reshape(1,-1)

# model path
path_model = '/content/drive/MyDrive/Colab Notebooks/orl_face_model.pkl';
# load the trained model
face_model = joblib.load(path_model)


# predict the id of the query image
id = face_model.predict(feat_query)
print("User id predicted is :",int(id[0]))


path = "/content/drive/MyDrive/Colab Notebooks/orl_face/orl_face/u%d/%d.png"%(id[0],1)

im_pred = mimg.imread(path)

plt.figure(1,(8,5))
plt.subplot(1,2,1)
plt.imshow(im,cmap='gray')
plt.axis('off')
plt.title("Query image")

plt.subplot(1,2,2)
plt.imshow(im_pred,cmap='gray')
plt.axis('off')
plt.title("predicted user")
# Out:
# User id predicted is : 39
# Text(0.5, 1.0, 'predicted user')

# %% [markdown]
# #False-Positive!

# %% [markdown]
# #Now, working on Generating an Computer Applications to analyze the Brain Tumor Problem.

# %%
#Now, unzip the tumor files.
# !unzip '/content/drive/MyDrive/Colab Notebooks/orl_face/new_train-20240708T093236Z-001.zip' -d '/content/drive/MyDrive/Colab Notebooks'
# Out:
# Archive:  /content/drive/MyDrive/Colab Notebooks/orl_face/new_train-20240708T093236Z-001.zip
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(36).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(26).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(3).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(12).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(49).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(21).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(28).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(17).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(10).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(29).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(47).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(18).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(43).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(23).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(2).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(48).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(24).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(19).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(50).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(1).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(22).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(42).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(32).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(9).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(13).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(44).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(61).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(34).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(7).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(58).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(15).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(60).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(5).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(27).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(45).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(53).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(35).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(20).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(4).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(38).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(51).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(46).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(30).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(57).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(55).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(33).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(37).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(52).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(41).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(11).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(39).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(54).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(8).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(40).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(56).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(16).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(14).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(25).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(31).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(59).png
#   inflating: /content/drive/MyDrive/Colab Notebooks/new_train/d(6).png

# %%
#Finding the Tumor in the Brain with the White-Spot.
import matplotlib.pyplot as plt;
import matplotlib.image as mimg;
import numpy as np;
plt.figure(1,figsize=(10,10));
for i in range(1,62,1):
  path='/content/drive/MyDrive/Colab Notebooks/new_train/d(%d).png'%(i);
  imag=mimg.imread(path);
  plt.subplot(8,8,i);
  plt.imshow(imag,cmap='gray');
  plt.title(i);
  plt.tight_layout();
  plt.axis("off");
  #plt.show();
