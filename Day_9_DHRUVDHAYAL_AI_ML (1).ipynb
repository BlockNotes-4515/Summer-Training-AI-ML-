# %% [markdown]
# #Neural Networks!

# %%
# Step-1: Now, we have to import the Libraries Inbuilt or Pre-defined.
from tensorflow import keras;
import numpy as np;
import matplotlib.pyplot as plt;

#Load the MNIST Datasets from the keras Library.
(Xtrain,ytrain),(Xtest,ytest)=keras.datasets.mnist.load_data();
print(Xtrain.shape,ytrain.shape);
print(Xtest.shape,ytest.shape);

#Data Scaling.
Xtrain=Xtrain/Xtrain.max();
Xtest=Xtest/Xtest.max();

print("\n --> Number of the Labels: ",len(np.unique(ytrain)));
# Out:
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)
#
#  --> Number of the Labels:  10

# %%
#Visualise the Values of the Data/Informations.
import numpy as np;
plt.figure(1,figsize=(6,8));
for i in range(1,36+1,1):
  temp=np.random.randint(0,60000);
  im=Xtrain[temp,:,:];
  lab=ytrain[temp];
  plt.subplot(6,6,i);
  plt.imshow(im,cmap='gray');
  plt.title(lab);
  plt.axis('off')

# %%
#Creating the Neural Networks.
nn_model=keras.Sequential(); #Create the empty 'nn' feed forward.
#Framework.
nn_model.add(keras.layers.Flatten(input_shape=(Xtrain.shape[1],Xtrain.shape[2])));  #An , Input Layer.

#Hidden Layers.
nn_model.add(keras.layers.Dense(128,activation='relu')); # Hidden Layer - 1.
nn_model.add(keras.layers.Dense(256,activation='relu')); # Hidden Layer - 2.
nn_model.add(keras.layers.Dense(256,activation='relu')); # Hidden Layer - 3.

#Output Layer.
nn_model.add(keras.layers.Dense(len(np.unique(ytrain))));

print(nn_model.summary());

#Optimizer Adding.
nn_model.compile(optimizer='SGD',loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy']) # Changed 'Loss' to 'loss'
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_7 (Flatten)         (None, 784)               0
#
#  dense_28 (Dense)            (None, 128)               100480
#
#  dense_29 (Dense)            (None, 256)               33024
#
#  dense_30 (Dense)            (None, 256)               65792
#
#  dense_31 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 201866 (788.54 KB)
# Trainable params: 201866 (788.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
#TRrain the model for the Xtrain and Ytrain.
history=nn_model.fit(Xtrain,ytrain,epochs=20);
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 8s 3ms/step - loss: 0.6578 - accuracy: 0.8235
# Epoch 2/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2777 - accuracy: 0.9195
# Epoch 3/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2197 - accuracy: 0.9361
# Epoch 4/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1822 - accuracy: 0.9469
# Epoch 5/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1551 - accuracy: 0.9545
# Epoch 6/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1354 - accuracy: 0.9602
# Epoch 7/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1196 - accuracy: 0.9644
# Epoch 8/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1067 - accuracy: 0.9688
# Epoch 9/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0963 - accuracy: 0.9717
# Epoch 10/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0869 - accuracy: 0.9747
# Epoch 11/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0792 - accuracy: 0.9766
# Epoch 12/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0720 - accuracy: 0.9789
# Epoch 13/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0660 - accuracy: 0.9807
# Epoch 14/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0604 - accuracy: 0.9825
# Epoch 15/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0557 - accuracy: 0.9836
# Epoch 16/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0509 - accuracy: 0.9852
# Epoch 17/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0471 - accuracy: 0.9862
# Epoch 18/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0437 - accuracy: 0.9880
# Epoch 19/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0403 - accuracy: 0.9881
# Epoch 20/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0370 - accuracy: 0.9898

# %%
print(Xtrain.min," - ",Xtrain.max());
# Out:
# <built-in method min of numpy.ndarray object at 0x7a53576e6850>  -  1.0

# %%
# visualize the training loss and acc
plt.figure(1,figsize=(4,2));
plt.plot(history.epoch,history.history['loss'],'--ko');
plt.grid('on');
plt.title('Training loss graph ');
plt.xlabel('Epochs');
plt.ylabel('Loss');

plt.figure(2,figsize=(4,2));
plt.plot(history.epoch,history.history['accuracy'],'--ko');
plt.grid('on');
plt.title('Training accuracy graph ');
plt.xlabel('Epochs');
plt.ylabel('Accuracy');

# %%
#Now, Evaluate the Test Data.
[loss,acc]=nn_model.evaluate(Xtest,ytest);
print("\n 1. Loss Values: ",loss);
print("\n 2. Test Accuracy: ",acc);
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0733 - accuracy: 0.9771
#
#  1. Loss Values:  0.0732819065451622
#
#  2. Test Accuracy:  0.9771000146865845

# %% [markdown]
# #Importing the Fashion Datsets.

# %%
# Step-1: Now, we have to import the Libraries Inbuilt or Pre-defined.
from tensorflow import keras;
import numpy as np;
import matplotlib.pyplot as plt;

#Load the MNIST Datasets from the keras Library.
(Xtrain,ytrain),(Xtest,ytest)=keras.datasets.fashion_mnist.load_data();
print(Xtrain.shape,ytrain.shape);
print(Xtest.shape,ytest.shape);

#Data Scaling.
Xtrain=Xtrain/Xtrain.max();
Xtest=Xtest/Xtest.max();

print("\n --> Number of the Labels: ",len(np.unique(ytrain)));
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)
#
#  --> Number of the Labels:  10

# %%
#Visualise the Values of the Data/Informations.
import numpy as np;
plt.figure(1,figsize=(6,8));
for i in range(1,36+1,1):
  temp=np.random.randint(0,60000);
  im=Xtrain[temp,:,:];
  lab=ytrain[temp];
  plt.subplot(6,6,i);
  plt.imshow(im,cmap='gray');
  plt.title(lab);
  plt.axis('off')

# %%
#Creating the Neural Networks.
nn_model=keras.Sequential(); #Create the empty 'nn' feed forward.
#Framework.
nn_model.add(keras.layers.Flatten(input_shape=(Xtrain.shape[1],Xtrain.shape[2])));  #An , Input Layer.

#Hidden Layers.
nn_model.add(keras.layers.Dense(128,activation='relu')); # Hidden Layer - 1.
nn_model.add(keras.layers.Dense(256,activation='relu')); # Hidden Layer - 2.
nn_model.add(keras.layers.Dense(256,activation='relu')); # Hidden Layer - 3.

#Output Layer.
nn_model.add(keras.layers.Dense(len(np.unique(ytrain))));

print(nn_model.summary());

#Optimizer Adding.
nn_model.compile(optimizer='SGD',loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy']) # Changed 'Loss' to 'loss'
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  dense_3 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 201866 (788.54 KB)
# Trainable params: 201866 (788.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
#TRrain the model for the Xtrain and Ytrain.
history=nn_model.fit(Xtrain,ytrain,epochs=20);
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.7598 - accuracy: 0.7425
# Epoch 2/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4953 - accuracy: 0.8260
# Epoch 3/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4412 - accuracy: 0.8453
# Epoch 4/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4105 - accuracy: 0.8548
# Epoch 5/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3868 - accuracy: 0.8626
# Epoch 6/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3700 - accuracy: 0.8680
# Epoch 7/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3549 - accuracy: 0.8720
# Epoch 8/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3415 - accuracy: 0.8766
# Epoch 9/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3322 - accuracy: 0.8795
# Epoch 10/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3227 - accuracy: 0.8819
# Epoch 11/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3129 - accuracy: 0.8857
# Epoch 12/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3073 - accuracy: 0.8885
# Epoch 13/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2988 - accuracy: 0.8913
# Epoch 14/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2928 - accuracy: 0.8924
# Epoch 15/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2857 - accuracy: 0.8956
# Epoch 16/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2798 - accuracy: 0.8969
# Epoch 17/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2735 - accuracy: 0.8989
# Epoch 18/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2685 - accuracy: 0.9009
# Epoch 19/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2636 - accuracy: 0.9027
# Epoch 20/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2595 - accuracy: 0.9037

# %%
# visualize the training loss and acc
plt.figure(1,figsize=(4,2));
plt.plot(history.epoch,history.history['loss'],'--ko');
plt.grid('on');
plt.title('Training loss graph ');
plt.xlabel('Epochs');
plt.ylabel('Loss');

plt.figure(2,figsize=(4,2));
plt.plot(history.epoch,history.history['accuracy'],'--ko');
plt.grid('on');
plt.title('Training accuracy graph ');
plt.xlabel('Epochs');
plt.ylabel('Accuracy');

# %%
#Now, Evaluate the Test Data.
[loss,acc]=nn_model.evaluate(Xtest,ytest);
print("\n 1. Loss Values: ",loss);
print("\n 2. Test Accuracy: ",acc);
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3427 - accuracy: 0.8787
#
#  1. Loss Values:  0.34272846579551697
#
#  2. Test Accuracy:  0.8787000179290771

# %% [markdown]
# #CIFAR DATSETS.

# %%
# Step-1: Now, we have to import the Libraries Inbuilt or Pre-defined.
from tensorflow import keras;
import numpy as np;
import matplotlib.pyplot as plt;

#Load the MNIST Datasets from the keras Library.
(Xtrain,ytrain),(Xtest,ytest)=keras.datasets.cifar10.load_data();
print(Xtrain.shape,ytrain.shape);
print(Xtest.shape,ytest.shape);

#Data Scaling.
Xtrain=Xtrain/Xtrain.max();
Xtest=Xtest/Xtest.max();

print("\n --> Number of the Labels: ",len(np.unique(ytrain)));
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step
# (50000, 32, 32, 3) (50000, 1)
# (10000, 32, 32, 3) (10000, 1)
#
#  --> Number of the Labels:  10

# %%
#Visualise the Values of the Data/Informations.
import numpy as np;
plt.figure(1,figsize=(6,8));
for i in range(1,36+1,1):
  temp=np.random.randint(0,50000); # Generate random integers within the valid range
  im=Xtrain[temp,:,:];
  lab=ytrain[temp];
  plt.subplot(6,6,i);
  plt.imshow(im,cmap='gray');
  plt.title(lab);
  plt.axis('off')

# %%
#Creating the Neural Networks.
nn_model=keras.Sequential(); #Create the empty 'nn' feed forward.
#Framework.
nn_model.add(keras.layers.Flatten(input_shape=(Xtrain.shape[1],Xtrain.shape[2], Xtrain.shape[3])));  #An , Input Layer. # Added Xtrain.shape[3] to account for color channels

#Hidden Layers.
nn_model.add(keras.layers.Dense(128,activation='relu')); # Hidden Layer - 1.
nn_model.add(keras.layers.Dense(256,activation='relu')); # Hidden Layer - 2.
nn_model.add(keras.layers.Dense(256,activation='relu')); # Hidden Layer - 3.

#Output Layer.
nn_model.add(keras.layers.Dense(len(np.unique(ytrain)))); # Removed the dense layer that was causing the shape mismatch

print(nn_model.summary());

#Optimizer Adding.
nn_model.compile(optimizer='SGD',loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy']) # Changed 'Loss' to 'loss'
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_3 (Flatten)         (None, 3072)              0
#
#  dense_13 (Dense)            (None, 128)               393344
#
#  dense_14 (Dense)            (None, 256)               33024
#
#  dense_15 (Dense)            (None, 256)               65792
#
#  dense_16 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 494730 (1.89 MB)
# Trainable params: 494730 (1.89 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
#TRrain the model for the Xtrain and Ytrain.
history=nn_model.fit(Xtrain,ytrain,epochs=50);
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.9024 - accuracy: 0.6803
# Epoch 2/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.8890 - accuracy: 0.6827
# Epoch 3/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.8769 - accuracy: 0.6889
# Epoch 4/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.8622 - accuracy: 0.6938
# Epoch 5/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.8517 - accuracy: 0.6968
# Epoch 6/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.8358 - accuracy: 0.7031
# Epoch 7/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.8266 - accuracy: 0.7070
# Epoch 8/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.8128 - accuracy: 0.7114
# Epoch 9/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.8020 - accuracy: 0.7156
# Epoch 10/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.7930 - accuracy: 0.7176
# Epoch 11/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.7765 - accuracy: 0.7260
# Epoch 12/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.7645 - accuracy: 0.7300
# Epoch 13/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.7533 - accuracy: 0.7329
# Epoch 14/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.7440 - accuracy: 0.7350
# Epoch 15/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.7276 - accuracy: 0.7406
# Epoch 16/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.7196 - accuracy: 0.7435
# Epoch 17/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.7040 - accuracy: 0.7494
# Epoch 18/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.6976 - accuracy: 0.7528
# Epoch 19/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.6850 - accuracy: 0.7585
# Epoch 20/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.6724 - accuracy: 0.7633
# Epoch 21/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.6623 - accuracy: 0.7635
# Epoch 22/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.6465 - accuracy: 0.7715
# Epoch 23/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.6365 - accuracy: 0.7733
# Epoch 24/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.6263 - accuracy: 0.7760
# Epoch 25/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.6156 - accuracy: 0.7813
# Epoch 26/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.6038 - accuracy: 0.7860
# Epoch 27/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.5920 - accuracy: 0.7914
# Epoch 28/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5827 - accuracy: 0.7933
# Epoch 29/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5718 - accuracy: 0.7970
# Epoch 30/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.5615 - accuracy: 0.8009
# Epoch 31/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5520 - accuracy: 0.8043
# Epoch 32/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.5409 - accuracy: 0.8100
# Epoch 33/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5303 - accuracy: 0.8133
# Epoch 34/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.5203 - accuracy: 0.8162
# Epoch 35/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5110 - accuracy: 0.8185
# Epoch 36/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.5024 - accuracy: 0.8206
# Epoch 37/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.4952 - accuracy: 0.8253
# Epoch 38/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4813 - accuracy: 0.8299
# Epoch 39/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.4753 - accuracy: 0.8304
# Epoch 40/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4661 - accuracy: 0.8354
# Epoch 41/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.4570 - accuracy: 0.8382
# Epoch 42/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4509 - accuracy: 0.8398
# Epoch 43/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.4327 - accuracy: 0.8484
# Epoch 44/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4199 - accuracy: 0.8515
# Epoch 45/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4195 - accuracy: 0.8524
# Epoch 46/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.4139 - accuracy: 0.8551
# Epoch 47/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4061 - accuracy: 0.8570
# Epoch 48/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.4000 - accuracy: 0.8590
# Epoch 49/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.3900 - accuracy: 0.8627
# Epoch 50/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.3827 - accuracy: 0.8651

# %%
# visualize the training loss and acc
plt.figure(1,figsize=(4,2));
plt.plot(history.epoch,history.history['loss'],'--ko');
plt.grid('on');
plt.title('Training loss graph ');
plt.xlabel('Epochs');
plt.ylabel('Loss');

plt.figure(2,figsize=(4,2));
plt.plot(history.epoch,history.history['accuracy'],'--ko');
plt.grid('on');
plt.title('Training accuracy graph ');
plt.xlabel('Epochs');
plt.ylabel('Accuracy');

# %%
#Now, Evaluate the Test Data.
[loss,acc]=nn_model.evaluate(Xtest,ytest);
print("\n 1. Loss Values: ",loss);
+print("\n 2. Test Accuracy: ",acc);
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 2.1509 - accuracy: 0.5262
#
#  1. Loss Values:  2.150902032852173
#
#  2. Test Accuracy:  0.526199996471405
